timesnew=np.genfromtxt('timey2.txt',dtype='float',delimiter=',',skip_header=0)
times4=np.genfromtxt('timey4.txt',dtype='float',delimiter=',',skip_header=0)

# %%
# Out:
# 14.859585338711922
# 43134

# %%
x=np.arange(0,np.size(timesnew),1)
plt.scatter(x,timesnew,s=1)
plt.show()
#print(sp.stats.mode(timesnew))
print(len(timesnew))
# Out:
# <div id='00a53b7b-68dd-4b85-b21d-792468c8ccee'></div>
# 20595

# %%
xaxis=np.array([])
yaxis=np.array([])
lengthparam=10000
for i in range(6,20,1):
    j=np.where(np.logical_and((timesnew[(len(timesnew)-lengthparam):len(timesnew)]<i+1),(timesnew[(len(timesnew)-lengthparam):len(timesnew)]>i)))
    print('Between',i,'and',i+1,'seconds:',len(timesnew[(len(timesnew)-lengthparam):len(timesnew)][j]))
    print('Mode in class:',sp.stats.mode(timesnew[(len(timesnew)-lengthparam):len(timesnew)][j]))
    print('Percentage incidence:',len(timesnew[(len(timesnew)-lengthparam):len(timesnew)][j])*100/lengthparam)
    print()
    
    xaxis=np.append(xaxis,[i])
    yaxis=np.append(yaxis,[len(timesnew[(len(timesnew)-lengthparam):len(timesnew)][j])])
plt.bar(xaxis,yaxis)
plt.show()
print('mode:',sp.stats.mode((timesnew[(len(timesnew)-lengthparam):len(timesnew)])))
print('count: ',len(timesnew[(len(timesnew)-lengthparam):len(timesnew)]))
print('mean:',np.mean((timesnew[(len(timesnew)-lengthparam):len(timesnew)])))
print('std:',np.std((timesnew[(len(timesnew)-lengthparam):len(timesnew)])))
# Out:
# Between 6 and 7 seconds: 1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-0a7089c3f142> in <module>
#       5     j=np.where(np.logical_and((timesnew[(len(timesnew)-lengthparam):len(timesnew)]<i+1),(timesnew[(len(timesnew)-lengthparam):len(timesnew)]>i)))
#       6     print('Between',i,'and',i+1,'seconds:',len(timesnew[(len(timesnew)-lengthparam):len(timesnew)][j]))
# ----> 7     print('Mode in class:',sp.stats.mode(timesnew[(len(timesnew)-lengthparam):len(timesnew)][j]))
#       8     print('Percentage incidence:',len(timesnew[(len(timesnew)-lengthparam):len(timesnew)][j])*100/lengthparam)
#       9     print()
#
# NameError: name 'sp' is not defined

# %%
lengthparam=10000
randomnoise=np.array([])
randomnoise3=np.array([])
for i in range(lengthparam):
    if len(str(timesnew[i])) < 4:
        pass
    elif str(timesnew[i])[-4] == ".":
        temp=str(timesnew[i])[-2:]
    elif str(timesnew[i])[-2] == ".":
        temp='00'
    else:
        temp=str(timesnew[i])[-1]+'0'
    randomnoise=np.append(randomnoise,[int(temp)])
    point=str(timesnew[i]).find('.')
    randomnoise3=np.append(randomnoise3,(str(timesnew[i])[point-1]))

ks=[]
for j in range(99):
    k=np.where(randomnoise==j)
    #print(j,'occurs with frequency:',100*len(k[0])/lengthparam)
    ks=np.append(ks,100*len(k[0])/lengthparam)

print('min:',np.where(ks==min(ks))[0],'with freq',min(ks),'and max:',np.where(ks==max(ks))[0],'with freq',max(ks))
plt.bar(np.arange(0,99,1),ks)
plt.show()
print(np.where(ks>1.7))
print(np.where(ks<0.3))
# Out:
# min: [76] with freq 0.09 and max: [74] with freq 2.18
# <div id='a0c446a4-e9f6-4a5f-91ed-d8cf91a95ccb'></div>
# (array([ 2,  6, 10, 14, 18, 22, 26, 30, 34, 38, 41, 42, 46, 50, 54, 57, 58,
#        62, 66, 70, 74, 78, 82, 86, 90, 94, 98], dtype=int32),)
# (array([ 0,  4,  8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64,
#        68, 72, 76, 80, 84, 88, 92, 96], dtype=int32),)
